# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Surname'].value_counts().sum()
# Out:
# 10000

# %%
df=df.drop(['RowNumber','CustomerId','Surname'],axis=1)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder=LabelEncoder()

# %%
df['Gender']=LabelEncoder.fit_transform(df['Gender'])

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df=pd.get_dummies(data=df,columns=['Geography']).astype(int)
df
# Out:
#       CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2        0              1          1
# 1             608       0   41       1    83807              1          0
# 2             502       0   42       8   159660              3          1
# 3             699       0   39       1        0              2          0
# 4             850       0   43       2   125510              1          1
# ...           ...     ...  ...     ...      ...            ...        ...
# 9995          771       1   39       5        0              2          1
# 9996          516       1   35      10    57369              1          1
# 9997          709       0   36       7        0              1          0
# 9998          772       1   42       3    75075              2          1
# 9999          792       0   28       4   130142              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# ...

# %%
df
# Out:
#       CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2        0              1          1
# 1             608       0   41       1    83807              1          0
# 2             502       0   42       8   159660              3          1
# 3             699       0   39       1        0              2          0
# 4             850       0   43       2   125510              1          1
# ...           ...     ...  ...     ...      ...            ...        ...
# 9995          771       1   39       5        0              2          1
# 9996          516       1   35      10    57369              1          1
# 9997          709       0   36       7        0              1          0
# 9998          772       1   42       3    75075              2          1
# 9999          792       0   28       4   130142              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int32
#  1   Gender             10000 non-null  int32
#  2   Age                10000 non-null  int32
#  3   Tenure             10000 non-null  int32
#  4   Balance            10000 non-null  int32
#  5   NumOfProducts      10000 non-null  int32
#  6   HasCrCard          10000 non-null  int32
#  7   IsActiveMember     10000 non-null  int32
#  8   EstimatedSalary    10000 non-null  int32
#  9   Exited             10000 non-null  int32
#  10  Geography_France   10000 non-null  int32
#  11  Geography_Germany  10000 non-null  int32
#  12  Geography_Spain    10000 non-null  int32
# dtypes: int32(13)
# memory usage: 507.9 KB

# %%
df.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited',
#        'Geography_France', 'Geography_Germany', 'Geography_Spain'],
#       dtype='object')

# %%
tenure_churn_no=df[df.Exited==0].Tenure
tenure_churn_yes=df[df.Exited==1].Tenure

# %%
plt.hist([tenure_churn_yes,tenure_churn_no],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
import matplotlib.pyplot as plt

# Set up the figure and axes
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Histogram for CreditScore
axes[0, 0].hist(df['CreditScore'], bins=20, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Distribution of CreditScore')
axes[0, 0].set_xlabel('CreditScore')
axes[0, 0].set_ylabel('Frequency')

# Histogram for Age
axes[0, 1].hist(df['Age'], bins=20, color='salmon', edgecolor='black')
axes[0, 1].set_title('Distribution of Age')
axes[0, 1].set_xlabel('Age')
axes[0, 1].set_ylabel('Frequency')

# Histogram for Balance
axes[1, 0].hist(df['Balance'], bins=20, color='lightgreen', edgecolor='black')
axes[1, 0].set_title('Distribution of Balance')
axes[1, 0].set_xlabel('Balance')
axes[1, 0].set_ylabel('Frequency')

# Histogram for EstimatedSalary
axes[1, 1].hist(df['EstimatedSalary'], bins=20, color='orange', edgecolor='black')
axes[1, 1].set_title('Distribution of EstimatedSalary')
axes[1, 1].set_xlabel('EstimatedSalary')
axes[1, 1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

# Box plot for Age
sns.boxplot(y='Age', data=df, ax=axes[0])
axes[0].set_title('Distribution of Age')

# Box plot for CreditScore
sns.boxplot(y='CreditScore', data=df, ax=axes[1])
axes[1].set_title('Distribution of CreditScore')

# Box plot for EstimatedSalary
sns.boxplot(y='EstimatedSalary', data=df, ax=axes[2])
axes[2].set_title('Distribution of EstimatedSalary')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
numerical_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary', 'Exited']

# Compute the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Set up the figure and axes
plt.figure(figsize=(10, 8))

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Set plot title
plt.title('Correlation Heatmap')

# Show plot
plt.show()

# %%
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2        0              1          1
# 1          608       0   41       1    83807              1          0
# 2          502       0   42       8   159660              3          1
# 3          699       0   39       1        0              2          0
# 4          850       0   43       2   125510              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0               1           101348       1                 1
# 1               1           112542       0                 0
# 2               0           113931       1                 1
# 3               0            93826       0                 1
# 4               1            79084       0                 0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# 2                  0                0
# ...

# %%
X=df.drop('Exited',axis=1)
y=df['Exited']

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model=keras.Sequential([
    keras.layers.Dense(20,input_shape=(12,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.6720 - loss: 816.5910
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.6941 - loss: 71.6412
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.6885 - loss: 62.6455
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.6726 - loss: 45.3051
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.6622 - loss: 45.5853
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.6815 - loss: 42.7937
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.6675 - loss: 27.4494
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.6800 - loss: 28.9253
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.6768 - loss: 30.1989
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.6819 - loss: 28.5717
# Epoch 11/50
# ...

# %%
model=keras.Sequential([
    keras.layers.Dense(20,input_shape=(12,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - accuracy: 0.6899 - loss: 2044.2089
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.6528 - loss: 83.5691
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.6713 - loss: 40.8816
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.6796 - loss: 36.2829
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.6654 - loss: 38.4134
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.6750 - loss: 34.8437
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.6840 - loss: 37.0151
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - accuracy: 0.6732 - loss: 30.9289
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.6887 - loss: 28.6979
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - accuracy: 0.6814 - loss: 33.1860
# Epoch 11/100
# ...

# %%
model=keras.Sequential([
    keras.layers.Dense(20,input_shape=(12,),activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',loss="binary_crossentropy",metrics=["accuracy"])

model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step - accuracy: 0.5510 - loss: 5331.6567
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.7049 - loss: 148.8007
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.6973 - loss: 61.8357
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.6981 - loss: 33.7081
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.6806 - loss: 20.6013
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.7020 - loss: 22.7463
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.7044 - loss: 29.6731
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.6845 - loss: 21.8565
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.6917 - loss: 23.4464
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.6876 - loss: 22.6210
# Epoch 11/50
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.8141 - loss: 16.7813
# [17.54082679748535, 0.8075000047683716]

# %%
yp=model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step

# %%
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = accuracy_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
recall = recall_score(y_test, y_pred_binary)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.8075
# Precision: 0.5733333333333334
# Recall: 0.10858585858585859
